# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/8.1 MB 11.8 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.1 MB 10.5 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 10.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 10.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ----------- ---------------------------- 2.1/7.0 MB 9.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.2/7.0 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.0/7.0 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 9.2 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/7 [pyparsing]
# ...

# %%
import pandas as pd
import matplotlib

# %%
df_fact_bookings= pd.read_csv("C:/Users/Vedant Raut/64101194a2364 (3)/source-code/3_project_hospitality_analysis/datasets/fact_bookings.csv")

# %%
 # Data Exploration

# %%
df_fact_bookings.head(5)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_fact_bookings.shape
# Out:
# (134590, 12)

# %%
df_fact_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_fact_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_fact_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_fact_bookings.booking_platform.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_fact_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_fact_bookings.revenue_generated.min(),df_fact_bookings.revenue_generated.max()
# Out:
# (np.int64(6500), np.int64(28560000))

# %%
df_dim_date= pd.read_csv("C:/Users/Vedant Raut/64101194a2364 (3)/source-code/3_project_hospitality_analysis/datasets/dim_date.csv")
df_dim_hotels= pd.read_csv("C:/Users/Vedant Raut/64101194a2364 (3)/source-code/3_project_hospitality_analysis/datasets/dim_hotels.csv")
df_dim_rooms= pd.read_csv("C:/Users/Vedant Raut/64101194a2364 (3)/source-code/3_project_hospitality_analysis/datasets/dim_rooms.csv")

# %%
df_dim_hotels.shape
# Out:
# (25, 4)

# %%
df_dim_hotels.head(4)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi

# %%
df_dim_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_dim_hotels.city.value_counts()
# Out:
# city
# Mumbai       8
# Hyderabad    6
# Bangalore    6
# Delhi        5
# Name: count, dtype: int64

# %%
df_dim_hotels.city.value_counts().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %%
# Read aggregated_bookings data in dataframe

df_fact_aggregated_bookings= pd.read_csv("C:/Users/Vedant Raut/64101194a2364 (3)/source-code/3_project_hospitality_analysis/datasets/fact_aggregated_bookings.csv")

# %%
df_fact_aggregated_bookings.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
type(df_fact_aggregated_bookings)
# Out:
# pandas.core.frame.DataFrame

# %%
# 1. Find out unique property ids in aggregate bookings dataset

df_fact_aggregated_bookings.property_id.unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560])

# %%
# 2. Find out total bookings per property_id

df_fact_aggregated_bookings.groupby('property_id')["successful_bookings"].sum()
# Out:
# property_id
# 16558    3153
# 16559    7338
# 16560    4693
# 16561    4418
# 16562    4820
# 16563    7211
# 17558    5053
# 17559    6142
# 17560    6013
# 17561    5183
# 17562    3424
# 17563    6337
# 17564    3982
# 18558    4475
# 18559    5256
# 18560    6638
# 18561    6458
# 18562    7333
# 18563    4737
# 19558    4400
# 19559    4729
# 19560    6079
# 19561    5736
# 19562    5812
# 19563    5413
# Name: successful_bookings, dtype: int64

# %%
# 3. Find out days on which bookings are greater than capacity

df_fact_aggregated_bookings[df_fact_aggregated_bookings.successful_bookings > df_fact_aggregated_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
# 4. Find out properties that have highest capacity

df_fact_aggregated_bookings[df_fact_aggregated_bookings.capacity == df_fact_aggregated_bookings.capacity.max()]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 27          17558      1-May-22           RT2                   38      50.0
# 128         17558      2-May-22           RT2                   27      50.0
# 229         17558      3-May-22           RT2                   26      50.0
# 328         17558      4-May-22           RT2                   27      50.0
# 428         17558      5-May-22           RT2                   29      50.0
# ...           ...           ...           ...                  ...       ...
# 8728        17558     27-Jul-22           RT2                   22      50.0
# 8828        17558     28-Jul-22           RT2                   21      50.0
# 8928        17558     29-Jul-22           RT2                   23      50.0
# 9028        17558     30-Jul-22           RT2                   32      50.0
# 9128        17558     31-Jul-22           RT2                   30      50.0
#
# [92 rows x 5 columns]

# %%
 # Data Cleaning

# %%
df_fact_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_fact_bookings[df_fact_bookings.no_guests <=0]  # values less than 0
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
 df_fact_bookings[df_fact_bookings.no_guests > 0] # values greater than 0 (i ingnored avbove values)
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_fact_bookings = df_fact_bookings[df_fact_bookings.no_guests>0] 
df_fact_bookings.shape
# Out:
# (134578, 12)

# %%
df_fact_bookings.revenue_generated.min(),df_fact_bookings.revenue_generated.max() # we see revenue in millions so me need to remove those outliers
# Out:
# (np.int64(6500), np.int64(28560000))

# %%
avg , std = df_fact_bookings.revenue_generated.mean(), df_fact_bookings.revenue_generated.std()
avg, std
# Out:
# (np.float64(15378.036937686695), np.float64(93040.1549314641))

# %%
higher_limit = avg + 3*std
higher_limit
# Out:
# np.float64(294498.50173207896)

# %%
lower_limit = avg - 3*std
lower_limit
# Out:
# np.float64(-263742.4278567056)

# %%
df_fact_bookings[df_fact_bookings.revenue_generated > higher_limit]  # so these values are my outlierrs and i will remove that
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_fact_bookings[df_fact_bookings.revenue_generated < higher_limit] # revenue generated ouliers removed
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_fact_bookings = df_fact_bookings[df_fact_bookings.revenue_generated < higher_limit]

# %%
df_fact_bookings.shape
# Out:
# (134573, 12)

# %%
df_fact_bookings.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
higher_limit = df_fact_bookings.revenue_realized.mean() + 3* df_fact_bookings.revenue_realized.std()
higher_limit
# Out:
# np.float64(33479.358661845814)

# %%
df_dim_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_fact_bookings[df_fact_bookings.room_category =="RT4"].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
df_fact_bookings.isnull().sum()  # hchecking if there are any null values
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
df_fact_aggregated_bookings.info()   # checking null values
df_fact_aggregated_bookings.isnull().sum()  # hchecking if there are any null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9200 entries, 0 to 9199
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          9200 non-null   int64
#  1   check_in_date        9200 non-null   object
#  2   room_category        9200 non-null   object
#  3   successful_bookings  9200 non-null   int64
#  4   capacity             9198 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 359.5+ KB
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
df_fact_aggregated_bookings.capacity.fillna(df_fact_aggregated_bookings.capacity.median(), inplace  = True) #replace null values with median
# Out:
# C:\Users\Vedant Raut\AppData\Local\Temp\ipykernel_23520\1530970823.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_fact_aggregated_bookings.capacity.fillna(df_fact_aggregated_bookings.capacity.median(), inplace  = True) #replace null values with median

# %%
df_fact_aggregated_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9200 entries, 0 to 9199
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          9200 non-null   int64
#  1   check_in_date        9200 non-null   object
#  2   room_category        9200 non-null   object
#  3   successful_bookings  9200 non-null   int64
#  4   capacity             9200 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 359.5+ KB

# %%
# In aggregate bookings find out records that have successful_bookings value greater than capacity. Filter those record

df_fact_aggregated_bookings[df_fact_aggregated_bookings.successful_bookings > df_fact_aggregated_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_fact_aggregated_bookings.shape
# Out:
# (9200, 5)

# %%
df_fact_aggregated_bookings = df_fact_aggregated_bookings[df_fact_aggregated_bookings.successful_bookings <= df_fact_aggregated_bookings.capacity]
df_fact_aggregated_bookings.shape
# Out:
# (9194, 5)

# %%
# Data Transformation

# %%
df_fact_aggregated_bookings.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0

# %%
# created new column 'oct%'

df_fact_aggregated_bookings['oct%'] =  df_fact_aggregated_bookings.successful_bookings / df_fact_aggregated_bookings.capacity
df_fact_aggregated_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0
#
#        oct%
# 0  0.833333
# 1  0.933333
# 2  0.766667
# 4  0.947368
# 5  0.700000

# %%
df_fact_aggregated_bookings["oct%"] = df_fact_aggregated_bookings["oct%"].apply(lambda x: round(x*100, 2))
df_fact_aggregated_bookings.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0
#
#     oct%
# 0  83.33
# 1  93.33
# 2  76.67
# 4  94.74
# 5  70.00

# %%
# Insights Generation

# %%
 # 1. What is an average occupancy rate in each of the room categories? 

df_fact_aggregated_bookings.groupby("room_category")["oct%"].mean().round(2)
# Out:
# room_category
# RT1    57.89
# RT2    58.01
# RT3    58.03
# RT4    59.28
# Name: oct%, dtype: float64

# %%
df_dim_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df = pd.merge(df_fact_aggregated_bookings, df_dim_rooms, left_on="room_category", right_on="room_id") # joining 2 tables
df
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           16558      1-May-22           RT1                   18      19.0
# 4           17560      1-May-22           RT1                   28      40.0
# ...           ...           ...           ...                  ...       ...
# 9189        16563     31-Jul-22           RT4                   13      18.0
# 9190        16559     31-Jul-22           RT4                   13      18.0
# 9191        17558     31-Jul-22           RT4                    3       6.0
# 9192        19563     31-Jul-22           RT4                    3       6.0
# 9193        17561     31-Jul-22           RT4                    3       4.0
#
#        oct% room_id    room_class
# ...

# %%
df.groupby("room_class")["oct%"].mean().round(2)
# Out:
# room_class
# Elite           58.01
# Premium         58.03
# Presidential    59.28
# Standard        57.89
# Name: oct%, dtype: float64

# %%
df.drop("room_id",axis = 1,inplace = True) #dropping column room_id from above (axis = 1 means dont drop rows)

# %%
df
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           16558      1-May-22           RT1                   18      19.0
# 4           17560      1-May-22           RT1                   28      40.0
# ...           ...           ...           ...                  ...       ...
# 9189        16563     31-Jul-22           RT4                   13      18.0
# 9190        16559     31-Jul-22           RT4                   13      18.0
# 9191        17558     31-Jul-22           RT4                    3       6.0
# 9192        19563     31-Jul-22           RT4                    3       6.0
# 9193        17561     31-Jul-22           RT4                    3       4.0
#
#        oct%    room_class
# ...

# %%
# print average occupancy rate per city

# %%
df_dim_hotels
# Out:
#     property_id  property_name  category       city
# 0         16558   Atliq Grands    Luxury      Delhi
# 1         16559  Atliq Exotica    Luxury     Mumbai
# 2         16560     Atliq City  Business      Delhi
# 3         16561      Atliq Blu    Luxury      Delhi
# 4         16562      Atliq Bay    Luxury      Delhi
# 5         16563   Atliq Palace  Business      Delhi
# 6         17558   Atliq Grands    Luxury     Mumbai
# 7         17559  Atliq Exotica    Luxury     Mumbai
# 8         17560     Atliq City  Business     Mumbai
# 9         17561      Atliq Blu    Luxury     Mumbai
# 10        17562      Atliq Bay    Luxury     Mumbai
# 11        17563   Atliq Palace  Business     Mumbai
# 12        18558   Atliq Grands    Luxury  Hyderabad
# 13        18559  Atliq Exotica    Luxury  Hyderabad
# 14        18560     Atliq City  Business  Hyderabad
# 15        18561      Atliq Blu    Luxury  Hyderabad
# 16        18562      Atliq Bay    Luxury  Hyderabad
# ...

# %%
df1 = pd.merge(df,df_dim_hotels,on = "property_id")
df1
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           16558      1-May-22           RT1                   18      19.0
# 4           17560      1-May-22           RT1                   28      40.0
# ...           ...           ...           ...                  ...       ...
# 9189        16563     31-Jul-22           RT4                   13      18.0
# 9190        16559     31-Jul-22           RT4                   13      18.0
# 9191        17558     31-Jul-22           RT4                    3       6.0
# 9192        19563     31-Jul-22           RT4                    3       6.0
# 9193        17561     31-Jul-22           RT4                    3       4.0
#
# ...

# %%
df1.groupby("city")["oct%"].mean().round(2).plot(kind ="bar")
# Out:
# <Axes: xlabel='city'>

# %%
# when was occupance better. weekday or wweekend?

# %%
df_dim_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df1 = pd.merge(df1,df_dim_date,left_on = "check_in_date", right_on = "date")
df1
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           19563     10-May-22           RT3                   15      29.0
# 1           18560     10-May-22           RT1                   19      30.0
# 2           19562     10-May-22           RT1                   18      30.0
# 3           19563     10-May-22           RT1                   16      30.0
# 4           17558     10-May-22           RT1                   11      19.0
# ...           ...           ...           ...                  ...       ...
# 6492        16563     31-Jul-22           RT4                   13      18.0
# 6493        16559     31-Jul-22           RT4                   13      18.0
# 6494        17558     31-Jul-22           RT4                    3       6.0
# 6495        19563     31-Jul-22           RT4                    3       6.0
# 6496        17561     31-Jul-22           RT4                    3       4.0
#
# ...

# %%
df1.groupby("day_type")["oct%"].mean().round(2)
# Out:
# day_type
# weekeday    50.88
# weekend     72.34
# Name: oct%, dtype: float64

# %%
df1.drop("date",axis = 1,inplace = True)  # dropped column date from above

# %%
df1.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
#
#     oct% room_class property_name  category       city  mmm yy week no  \
# 0  51.72    Premium  Atliq Palace  Business  Bangalore  May 22    W 20
# 1  63.33   Standard    Atliq City  Business  Hyderabad  May 22    W 20
# 2  60.00   Standard     Atliq Bay    Luxury  Bangalore  May 22    W 20
#
#    day_type
# 0  weekeday
# 1  weekeday
# 2  weekeday

# %%
# In the mmonth of june what was the occupance rate for different citiess

# %%
df1["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_jun = df1[df1["mmm yy"]=="Jun 22"] # creating new dataframe just for june month
df_jun.head(3)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        19562     10-Jun-22           RT1                   19      30.0
# 2202        19563     10-Jun-22           RT1                   17      30.0
#
#        oct% room_class  property_name  category       city  mmm yy week no  \
# 2200  66.67   Standard  Atliq Exotica    Luxury     Mumbai  Jun 22    W 24
# 2201  63.33   Standard      Atliq Bay    Luxury  Bangalore  Jun 22    W 24
# 2202  56.67   Standard   Atliq Palace  Business  Bangalore  Jun 22    W 24
#
#       day_type
# 2200  weekeday
# 2201  weekeday
# 2202  weekeday

# %%
df_jun.groupby("city")["oct%"].mean().round(2).sort_values()
# Out:
# city
# Bangalore    56.44
# Mumbai       58.38
# Hyderabad    58.46
# Delhi        62.47
# Name: oct%, dtype: float64

# %%
df_aug = pd.read_csv("C:/Users/Vedant Raut/64101194a2364 (3)/source-code/3_project_hospitality_analysis/datasets/new_data_august.csv")
df_aug.head(5)
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# 3     01-Aug-22  Aug-22    W 32  weekeday                   30        40
# 4     01-Aug-22  Aug-22    W 32  weekeday                   20        26
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67
# 3   75.00
# 4   76.92

# %%
df_aug.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occ%'],
#       dtype='object')

# %%
df_aug.shape
# Out:
# (7, 13)

# %%
df1.shape
# Out:
# (6497, 13)

# %%
df2 = pd.concat([df1,df_aug],ignore_index = True, axis = 0)
df2.tail(5)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6499        19563     01-Aug-22           RT1                   23      30.0
# 6500        19558     01-Aug-22           RT1                   30      40.0
# 6501        19560     01-Aug-22           RT1                   20      26.0
# 6502        17561     01-Aug-22           RT1                   18      26.0
# 6503        17564     01-Aug-22           RT1                   10      16.0
#
#       oct% room_class  property_name  category       city  mmm yy week no  \
# 6499   NaN   Standard   Atliq Palace  Business  Bangalore  Aug-22    W 32
# 6500   NaN   Standard   Atliq Grands    Luxury  Bangalore  Aug-22    W 32
# 6501   NaN   Standard     Atliq City  Business  Bangalore  Aug-22    W 32
# 6502   NaN   Standard      Atliq Blu    Luxury     Mumbai  Aug-22    W 32
# 6503   NaN   Standard  Atliq Seasons  Business     Mumbai  Aug-22    W 32
#
#       day_type   occ%
# 6499  weekeday  76.67
# ...

# %%
# revenue realised per city

# %%
df_fact_bookings.head(5)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 7        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized
# ...

# %%
df_dim_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df3 = pd.merge(df_fact_bookings , df_dim_hotels, on = "property_id")
df3
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT12        16558     30-04-22    2022-05-01
# 1        May012216558RT15        16558     27-04-22    2022-05-01
# 2        May012216558RT16        16558     1/5/2022    2022-05-01
# 3        May012216558RT17        16558     28-04-22    2022-05-01
# 4        May012216558RT18        16558     26-04-22    2022-05-01
# ...                   ...          ...          ...           ...
# 134568   Jul312217564RT45        17564     30-07-22    2022-07-31
# 134569   Jul312217564RT46        17564     29-07-22    2022-07-31
# 134570   Jul312217564RT48        17564     30-07-22    2022-07-31
# 134571   Jul312217564RT49        17564     29-07-22    2022-07-31
# 134572  Jul312217564RT410        17564     31-07-22    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df3.groupby("city")["revenue_realized"].sum().sort_values()
# Out:
# city
# Delhi        294404488
# Hyderabad    325179310
# Bangalore    420383550
# Mumbai       668569251
# Name: revenue_realized, dtype: int64

# %%
# Print month by month revenue

# %%
df_dim_date.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday

# %%
df3.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi

# %%
df4 = pd.merge(df3,df_dim_date,left_on = "check_in_date", right_on = "date") # here i did not get output because date type is diff
df4.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi
#
#         date  mmm yy week no day_type
# 0 2022-05-01  May 22    W 19  weekend
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  datetime64[ns]
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_dim_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     datetime64[ns]
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.0+ KB

# %%
df_dim_date.date = pd.to_datetime(df_dim_date.date)

# %%
df_dim_date
# Out:
#          date  mmm yy week no  day_type
# 0  2022-05-01  May 22    W 19   weekend
# 1  2022-05-02  May 22    W 19  weekeday
# 2  2022-05-03  May 22    W 19  weekeday
# 3  2022-05-04  May 22    W 19  weekeday
# 4  2022-05-05  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87 2022-07-27  Jul 22    W 31  weekeday
# 88 2022-07-28  Jul 22    W 31  weekeday
# 89 2022-07-29  Jul 22    W 31  weekeday
# 90 2022-07-30  Jul 22    W 31   weekend
# 91 2022-07-31  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  datetime64[ns]
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df4["check_in_date"] = pd.to_datetime(df4["check_in_date"],format="mixed",dayfirst=True)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  datetime64[ns]
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df5 = pd.merge(df4,df_dim_date,left_on = "check_in_date", right_on = "date")
df5.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    ...  category   city     date_x mmm yy_x week no_x day_type_x     date_y  \
# 0  ...    Luxury  Delhi 2022-05-01   May 22      W 19    weekend 2022-05-01
# 1  ...    Luxury  Delhi 2022-05-01   May 22      W 19    weekend 2022-05-01
# 2  ...    Luxury  Delhi 2022-05-01   May 22      W 19    weekend 2022-05-01
#
#   mmm yy_y week no_y day_type_y
# ...

# %%
df5.groupby("mmm yy_x")["revenue_realized"].sum().sort_values()
# Out:
# mmm yy_x
# Jun 22    553925855
# Jul 22    572843348
# May 22    581767396
# Name: revenue_realized, dtype: int64

# %%
#Print revenue realized per hotel type
df5.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    ...  category   city     date_x mmm yy_x week no_x day_type_x     date_y  \
# 0  ...    Luxury  Delhi 2022-05-01   May 22      W 19    weekend 2022-05-01
# 1  ...    Luxury  Delhi 2022-05-01   May 22      W 19    weekend 2022-05-01
# 2  ...    Luxury  Delhi 2022-05-01   May 22      W 19    weekend 2022-05-01
#
#   mmm yy_y week no_y day_type_y
# ...

# %%
df5.groupby("property_name")["revenue_realized"].sum().sort_values()
# Out:
# property_name
# Atliq Seasons     66086735
# Atliq Grands     211462134
# Atliq Bay        259996918
# Atliq Blu        260851922
# Atliq City       285798439
# Atliq Palace     304081863
# Atliq Exotica    320258588
# Name: revenue_realized, dtype: int64

# %%
#Print average rating per city

# %%
df5.groupby("city")["ratings_given"].mean().sort_values().round(2)
# Out:
# city
# Bangalore    3.41
# Mumbai       3.65
# Hyderabad    3.66
# Delhi        3.78
# Name: ratings_given, dtype: float64

# %%
#Print a pie chart of revenue realized per booking platform

# %%
df5.groupby("booking_platform")["revenue_realized"].sum().plot(kind = "pie")
# Out:
# <Axes: ylabel='revenue_realized'>
